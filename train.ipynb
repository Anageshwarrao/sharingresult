# %%
library(readr)

analysis.anova <- read.csv("C:\\Users\\LENOVO\\Desktop\\train.csv", encoding = "UTF-8",
                           header = TRUE,
                           stringsAsFactors = FALSE,
                           strip.white = TRUE ,
                           sep = ',')

Sys.setlocale(category = "LC_ALL", "Russian")

#str(analysis.anova)

head(analysis.anova)
# Out:
# [1] "LC_COLLATE=Russian_Russia.1251;LC_CTYPE=Russian_Russia.1251;LC_MONETARY=Russian_Russia.1251;LC_NUMERIC=C;LC_TIME=Russian_Russia.1251"
#   item_id      user_id      region                city
# 1 b912c3c6a6ad e00f8ff2eaf9 Свердловская область  Екатеринбург
# 2 2dac0150717d 39aeb48f0017 Самарская область     Самара
# 3 ba83aefab5dc 91e2f88dd6e3 Ростовская область    Ростов-на-Дону
# 4 02996f1dd2ea bf5cccea572d Татарстан             Набережные Челны
# 5 7c90be56d2ab ef50846afc0b Волгоградская область Волгоград
# 6 51e0962387f7 bbfad0b1ad0a Татарстан             Чистополь
#   parent_category_name category_name              param_1
# 1 Личные вещи          Товары для детей и игрушки Постельные принадлежности
# 2 Для дома и дачи      Мебель и интерьер          Другое
# 3 Бытовая электроника  Аудио и видео              Видео, DVD и Blu-ray плееры
# 4 Личные вещи          Товары для детей и игрушки Автомобильные кресла
# 5 Транспорт            Автомобили                 С пробегом
# ...
